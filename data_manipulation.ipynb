# %% [raw]
# # Manipulação dos dados do MongoDB

# %%
from database_manipulation import conecta_collection

# %%
# Import da conexão com a base e collection
collection, client = conecta_collection("db_produtos","produtos")
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
collection.distinct("Categoria do Produto")
# Out:
# ['brinquedos',
#  'eletrodomesticos',
#  'eletronicos',
#  'esporte e lazer',
#  'instrumentos musicais',
#  'livros',
#  'moveis',
#  'utilidades domesticas']

# %%
query = {"Categoria do Produto": "livros"}

lista_livros = []
for doc in collection.find(query):
    lista_livros.append(doc)
# Out:
# {'_id': ObjectId('65542caf3392a707f3dcbd8d'), 'Produto': 'Modelagem preditiva', 'Categoria do Produto': 'livros', 'Preço': 92.45, 'Frete': 5.6096965236, 'Data da Compra': '01/01/2020', 'Vendedor': 'Thiago Silva', 'Local da compra': 'BA', 'Avaliação da compra': 1, 'Tipo de pagamento': 'cartao_credito', 'Quantidade de parcelas': 3, 'Latitude': -13.29, 'Longitude': -41.71}
# {'_id': ObjectId('65542caf3392a707f3dcbd8e'), 'Produto': 'Iniciando em programação', 'Categoria do Produto': 'livros', 'Preço': 43.84, 'Frete': 0.0, 'Data da Compra': '01/01/2020', 'Vendedor': 'Mariana Ferreira', 'Local da compra': 'SP', 'Avaliação da compra': 5, 'Tipo de pagamento': 'cartao_credito', 'Quantidade de parcelas': 1, 'Latitude': -22.19, 'Longitude': -48.79}
# ...
